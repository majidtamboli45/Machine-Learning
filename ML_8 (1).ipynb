# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn as sk
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/majid/Downloads/Datasets/WineQT.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4        5     0
# 1         9.8        5     1
# 2         9.8        5     2
# 3         9.8        6     3
# 4         9.4        5     4
# ...       ...      ...   ...
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597
#
# [1143 rows x 13 columns]

# %%
df.size
# Out:
# 14859

# %%
df.shape
# Out:
# (1143, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995570
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997845
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality           Id
# count  1143.000000  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     5.657043   804.969379
# std       0.156664     0.170399     1.082196     0.805824   463.997116
# min       2.740000     0.330000     8.400000     3.000000     0.000000
# 25%       3.205000     0.550000     9.500000     5.000000   411.000000
# 50%       3.310000     0.620000    10.200000     6.000000   794.000000
# 75%       3.400000     0.730000    11.100000     6.000000  1209.500000
# max       4.010000     2.000000    14.900000     8.000000  1597.000000

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df = df.drop(['Id'],axis =1)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1138     11.0        6
# 1139      9.5        6
# 1140     10.5        5
# 1141     11.2        6
# 1142     10.2        5
#
# [1143 rows x 12 columns]

# %%
sns.pairplot(df)

# %%
df.hist(figsize = (12 , 10) , bins = 20 , edgecolor = "black")
df.subtitle("Feature Distribution" , fontsize = 16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22232\1427564738.py in ?()
#       1 df.hist(figsize = (12 , 10) , bins = 20 , edgecolor = "black")
# ----> 2 df.subtitle("Feature Distribution" , fontsize = 16)
#       3 plt.show()
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'subtitle'

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr() , annot = True)
plt.title("Correlation Map")
plt.show()

# %%
num_features = [feature for feature in df.columns if df[feature].dtype != 'O']
print("Number of Numerical Features : " , len(num_features))
# Out:
# Number of Numerical Features :  12

# %%
cat_features = [feature for feature in df.columns if df[feature].dtype == 'O']
print("Number of Categorical Features : " , len(cat_features))
# Out:
# Number of Categorical Features :  0

# %%
dis_features = [feature for feature in num_features if len(df[feature].unique()) <= 25]
print("Number of discrete Features : ",len(dis_features))
print(dis_features)
# Out:
# Number of discrete Features :  1
# ['quality']

# %%
con_features = [feature for feature in num_features if feature not in dis_features]
print("Number of continuous Features :" , len(con_features))
# Out:
# Number of continuous Features : 11

# %%
x = df.drop('quality',axis = 1)
y = df['quality']

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1138     11.0
# 1139      9.5
# 1140     10.5
# 1141     11.2
# 1142     10.2
#
# [1143 rows x 11 columns]

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1138    6
# 1139    6
# 1140    5
# 1141    6
# 1142    5
# Name: quality, Length: 1143, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,train_size = 0.8 , random_state = 42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.ensemble import GradientBoostingRegressor
model = GradientBoostingRegressor()

# %%
model
# Out:
# GradientBoostingRegressor()

# %%
model.fit(x_train , y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([6.21399711, 6.22216303, 6.34631297, 6.22586914, 6.25540417,
#        6.32123775, 6.21399711, 6.34030966, 6.3604822 , 6.32123775,
#        6.36511547, 6.40515414, 6.26140748, 6.30706852, 6.31307183,
#        6.22216303, 6.40277952, 6.31307183, 6.28989236, 6.44102341,
#        6.30706852, 6.40277952, 6.30706852, 6.32415887, 6.34030966,
#        6.21399711, 6.35536915, 6.34030966, 6.2079938 , 6.31307183,
#        6.21399711, 6.31307183, 6.41417823, 6.32123775, 6.35447889,
#        6.21399711, 6.34030966, 6.34030966, 6.31307183, 6.58801342,
#        6.40515414, 6.18481434, 6.36577794, 6.19081765, 6.20498687,
#        6.21399711, 6.21399711, 6.37102274, 6.2079938 , 6.24123494,
#        6.40277952, 6.21399711, 6.31307183, 6.35447889, 6.30998964,
#        6.36363112, 6.25540417, 6.3604822 , 6.41932337, 6.2079938 ,
#        6.34030966, 6.31307183, 6.34030966, 6.35685351, 6.34030966,
#        6.2079938 , 6.35536915, 6.31307183, 6.24123494, 6.32123775,
#        6.39924688, 6.24723825, 6.40591626, 6.21399711, 6.21399711,
#        6.26140748, 6.40277952, 6.3886103 , 6.32005132, 6.35685351,
#        6.30706852, 6.21399711, 6.2736004 , 6.24723825, 6.30706852,
#        6.30706852, 6.19081765, 6.30706852, 6.22216303, 6.21399711,
#        6.21399711, 6.25540417, 6.19182357, 6.32123775, 6.24123494,
#        6.32123775, 6.30706852, 6.4860049 , 6.35447889, 6.31307183,
#        6.30706852, 6.31307183, 6.25540417, 6.31307183, 6.24723825,
#        6.34030966, 6.32123775, 6.32415887, 6.21399711, 6.42097575,
#        6.41026719, 6.35447889, 6.34030966, 6.3886103 , 6.24123494,
#        6.25540417, 6.26140748, 6.24949691, 6.34631297, 6.22216303,
#        6.31307183, 6.2079938 , 6.32123775, 6.42630146, 6.24723825,
#        6.30706852, 6.21399711, 6.21399711, 6.22221137, 6.35447889,
#        6.2079938 , 6.26140748, 6.36363112, 6.34030966, 6.40426388,
#        6.18481434, 6.23569715, 6.30998964, 6.24123494, 6.30706852,
#        6.38684434, 6.2079938 , 6.30706852, 6.2079938 , 6.32123775,
#        6.29101993, 6.34030966, 6.30706852, 6.13270169, 6.24123494,
#        6.42097575, 6.34030966, 6.42097575, 6.35447889, 6.35536915,
#        6.32123775, 6.30706852, 6.35977463, 6.35447889, 6.2637821 ,
#        6.22216303, 6.2079938 , 6.21399711, 6.34631297, 6.21399711,
#        6.28989236, 6.37102274, 6.34030966, 6.27960371, 6.35447889,
#        6.35536915, 6.34631297, 6.39609796, 6.32123775, 6.21399711,
#        6.35447889, 6.35977463, 6.407185  , 6.35447889, 6.21399711,
#        6.35536915, 6.32123775, 6.24594563, 6.31307183, 6.32123775,
#        6.2736004 , 6.35685351, 6.24123494, 6.46838612, 6.39009465,
#        6.32724106, 6.35447889, 6.3886103 , 6.35536915, 6.21399711,
#        6.30706852, 6.21399711, 6.36953838, 6.40515414, 6.32415887,
#        6.22216303, 6.21399711, 6.35447889, 6.30706852, 6.34030966,
#        6.22216303, 6.30706852, 6.3604822 , 6.35685351, 6.42097575,
#        6.24723825, 6.34030966, 6.32123775, 6.26140748, 6.30706852,
#        6.31307183, 6.31533048, 6.2079938 , 6.34030966, 6.39009465,
#        6.22816634, 6.36285682, 6.21399711, 6.22816634, 6.21399711,
#        6.30706852, 6.26140748, 6.20051133, 6.34030966])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error , r2_score
mae = mean_absolute_error(y_test , y_pred)
mse = mean_squared_error(y_test , y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test , y_pred)

# %%
print(mae)
# Out:
# 0.8204633174993791

# %%
print(mse)
# Out:
# 0.9497087780900861

# %%
print(rmse)
# Out:
# 0.9745300293423934

# %%
r2
# Out:
# -0.7066574611686034

# %%
plt.scatter(y_test , y_pred)
